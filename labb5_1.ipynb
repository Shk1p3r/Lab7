# %%
import pandas as pd
import random
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, ConfusionMatrixDisplay, confusion_matrix, classification_report
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
tf.keras.utils.set_random_seed(123)
random.seed(123)

# %% [markdown]
# ![Снимок экрана 2023-05-23 124828.png](attachment:d9e3e45e-8aa5-404d-92a0-fdc26b360133.png)

# %%
wine = datasets.load_wine(as_frame=True)

data = wine.data
target = wine.target
batchSize = 10
drop_out=0.2
unique=np.unique(target)
num_classes=3
wine
# Out:
# {'data':      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
#  0      14.23        1.71  2.43               15.6      127.0           2.80
#  1      13.20        1.78  2.14               11.2      100.0           2.65
#  2      13.16        2.36  2.67               18.6      101.0           2.80
#  3      14.37        1.95  2.50               16.8      113.0           3.85
#  4      13.24        2.59  2.87               21.0      118.0           2.80
#  ..       ...         ...   ...                ...        ...            ...
#  173    13.71        5.65  2.45               20.5       95.0           1.68
#  174    13.40        3.91  2.48               23.0      102.0           1.80
#  175    13.27        4.28  2.26               20.0      120.0           1.59
#  176    13.17        2.59  2.37               20.0      120.0           1.65
#  177    14.13        4.10  2.74               24.5       96.0           2.05
#
#       flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
#  0          3.06                  0.28             2.29             5.64  1.04
#  1          2.76                  0.26             1.28             4.38  1.05
#  2          3.24                  0.30             2.81             5.68  1.03
#  3          3.49                  0.24             2.18             7.80  0.86
#  4          2.69                  0.39             1.82             4.32  1.04
#  ..          ...                   ...              ...              ...   ...
#  173        0.61                  0.52             1.06             7.70  0.64
#  174        0.75                  0.43             1.41             7.30  0.70
#  175        0.69                  0.43             1.35            10.20  0.59
#  176        0.68                  0.53             1.46             9.30  0.60
#  177        0.76                  0.56             1.35             9.20  0.61
#
#       od280/od315_of_diluted_wines  proline
#  0                            3.92   1065.0
#  1                            3.40   1050.0
#  2                            3.17   1185.0
#  3                            3.45   1480.0
#  4                            2.93    735.0
#  ..                            ...      ...
#  173                          1.74    740.0
#  174                          1.56    750.0
#  175                          1.56    835.0
#  176                          1.62    840.0
#  177                          1.60    560.0
#
#  [178 rows x 13 columns],
#  'target': 0      0
#  1      0
#  2      0
#  3      0
#  4      0
#        ..
#  173    2
#  174    2
#  175    2
#  176    2
#  177    2
#  Name: target, Length: 178, dtype: int32,
#  'frame':      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
#  0      14.23        1.71  2.43               15.6      127.0           2.80
#  1      13.20        1.78  2.14               11.2      100.0           2.65
#  2      13.16        2.36  2.67               18.6      101.0           2.80
#  3      14.37        1.95  2.50               16.8      113.0           3.85
#  4      13.24        2.59  2.87               21.0      118.0           2.80
#  ..       ...         ...   ...                ...        ...            ...
#  173    13.71        5.65  2.45               20.5       95.0           1.68
#  174    13.40        3.91  2.48               23.0      102.0           1.80
#  175    13.27        4.28  2.26               20.0      120.0           1.59
#  176    13.17        2.59  2.37               20.0      120.0           1.65
#  177    14.13        4.10  2.74               24.5       96.0           2.05
#
#       flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
#  0          3.06                  0.28             2.29             5.64  1.04
#  1          2.76                  0.26             1.28             4.38  1.05
#  2          3.24                  0.30             2.81             5.68  1.03
#  3          3.49                  0.24             2.18             7.80  0.86
#  4          2.69                  0.39             1.82             4.32  1.04
#  ..          ...                   ...              ...              ...   ...
#  173        0.61                  0.52             1.06             7.70  0.64
#  174        0.75                  0.43             1.41             7.30  0.70
#  175        0.69                  0.43             1.35            10.20  0.59
#  176        0.68                  0.53             1.46             9.30  0.60
#  177        0.76                  0.56             1.35             9.20  0.61
#
#       od280/od315_of_diluted_wines  proline  target
#  0                            3.92   1065.0       0
#  1                            3.40   1050.0       0
#  2                            3.17   1185.0       0
#  3                            3.45   1480.0       0
#  4                            2.93    735.0       0
#  ..                            ...      ...     ...
#  173                          1.74    740.0       2
#  174                          1.56    750.0       2
#  175                          1.56    835.0       2
#  176                          1.62    840.0       2
#  177                          1.60    560.0       2
#
#  [178 rows x 14 columns],
#  'target_names': array(['class_0', 'class_1', 'class_2'], dtype='<U7'),
#  'DESCR': '.. _wine_dataset:\n\nWine recognition dataset\n------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 178 (50 in each of three classes)\n    :Number of Attributes: 13 numeric, predictive attributes and the class\n    :Attribute Information:\n \t\t- Alcohol\n \t\t- Malic acid\n \t\t- Ash\n\t\t- Alcalinity of ash  \n \t\t- Magnesium\n\t\t- Total phenols\n \t\t- Flavanoids\n \t\t- Nonflavanoid phenols\n \t\t- Proanthocyanins\n\t\t- Color intensity\n \t\t- Hue\n \t\t- OD280/OD315 of diluted wines\n \t\t- Proline\n\n    - class:\n            - class_0\n            - class_1\n            - class_2\n\t\t\n    :Summary Statistics:\n    \n    ============================= ==== ===== ======= =====\n                                   Min   Max   Mean     SD\n    ============================= ==== ===== ======= =====\n    Alcohol:                      11.0  14.8    13.0   0.8\n    Malic Acid:                   0.74  5.80    2.34  1.12\n    Ash:                          1.36  3.23    2.36  0.27\n    Alcalinity of Ash:            10.6  30.0    19.5   3.3\n    Magnesium:                    70.0 162.0    99.7  14.3\n    Total Phenols:                0.98  3.88    2.29  0.63\n    Flavanoids:                   0.34  5.08    2.03  1.00\n    Nonflavanoid Phenols:         0.13  0.66    0.36  0.12\n    Proanthocyanins:              0.41  3.58    1.59  0.57\n    Colour Intensity:              1.3  13.0     5.1   2.3\n    Hue:                          0.48  1.71    0.96  0.23\n    OD280/OD315 of diluted wines: 1.27  4.00    2.61  0.71\n    Proline:                       278  1680     746   315\n    ============================= ==== ===== ======= =====\n\n    :Missing Attribute Values: None\n    :Class Distribution: class_0 (59), class_1 (71), class_2 (48)\n    :Creator: R.A. Fisher\n    :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)\n    :Date: July, 1988\n\nThis is a copy of UCI ML Wine recognition datasets.\nhttps://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data\n\nThe data is the results of a chemical analysis of wines grown in the same\nregion in Italy by three different cultivators. There are thirteen different\nmeasurements taken for different constituents found in the three types of\nwine.\n\nOriginal Owners: \n\nForina, M. et al, PARVUS - \nAn Extendible Package for Data Exploration, Classification and Correlation. \nInstitute of Pharmaceutical and Food Analysis and Technologies,\nVia Brigata Salerno, 16147 Genoa, Italy.\n\nCitation:\n\nLichman, M. (2013). UCI Machine Learning Repository\n[https://archive.ics.uci.edu/ml]. Irvine, CA: University of California,\nSchool of Information and Computer Science. \n\n.. topic:: References\n\n  (1) S. Aeberhard, D. Coomans and O. de Vel, \n  Comparison of Classifiers in High Dimensional Settings, \n  Tech. Rep. no. 92-02, (1992), Dept. of Computer Science and Dept. of  \n  Mathematics and Statistics, James Cook University of North Queensland. \n  (Also submitted to Technometrics). \n\n  The data was used with many others for comparing various \n  classifiers. The classes are separable, though only RDA \n  has achieved 100% correct classification. \n  (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data)) \n  (All results using the leave-one-out technique) \n\n  (2) S. Aeberhard, D. Coomans and O. de Vel, \n  "THE CLASSIFICATION PERFORMANCE OF RDA" \n  Tech. Rep. no. 92-01, (1992), Dept. of Computer Science and Dept. of \n  Mathematics and Statistics, James Cook University of North Queensland. \n  (Also submitted to Journal of Chemometrics).\n',
#  'feature_names': ['alcohol',
#   'malic_acid',
#   'ash',
#   'alcalinity_of_ash',
#   'magnesium',
#   'total_phenols',
#   'flavanoids',
#   'nonflavanoid_phenols',
#   'proanthocyanins',
#   'color_intensity',
#   'hue',
#   'od280/od315_of_diluted_wines',
#   'proline']}

# %%
x_train, x_test, y_train,y_test = train_test_split(data, target,random_state = 1,test_size=0.5,shuffle=True)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
inp = tf.keras.layers.Input(shape=(13,)) 
dropout1 =  tf.keras.layers.Dropout(drop_out)(inp)
hidden_1 =  tf.keras.layers.Dense(80, activation='LeakyReLU')(dropout1)
out =  tf.keras.layers.Dense(3, activation='softmax')(hidden_1)

model1 = tf.keras.Model(inputs=inp, outputs=out)

# %%
model1.compile(optimizer = tf.keras.optimizers.Adagrad(),
               loss = 'mean_absolute_error',
               metrics=['accuracy'])
model1.fit(x_train,y_train,epochs=120,batch_size=batchSize)
# Out:
# Epoch 1/120
# 9/9 [==============================] - 1s 3ms/step - loss: 0.4912 - accuracy: 0.1573
# Epoch 2/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4908 - accuracy: 0.1910
# Epoch 3/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4954 - accuracy: 0.1685
# Epoch 4/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4891 - accuracy: 0.1798
# Epoch 5/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.1798
# Epoch 6/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4768 - accuracy: 0.2135
# Epoch 7/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4778 - accuracy: 0.2247
# Epoch 8/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4805 - accuracy: 0.2022
# Epoch 9/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.2584
# Epoch 10/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4686 - accuracy: 0.2809
# Epoch 11/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4679 - accuracy: 0.2360
# Epoch 12/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.2921
# Epoch 13/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4596 - accuracy: 0.2697
# Epoch 14/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4605 - accuracy: 0.2697
# Epoch 15/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.3596
# Epoch 16/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.3146
# Epoch 17/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.4045
# Epoch 18/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.3933
# Epoch 19/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4438 - accuracy: 0.3371
# Epoch 20/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4395 - accuracy: 0.3483
# Epoch 21/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4385 - accuracy: 0.3933
# Epoch 22/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4346 - accuracy: 0.4270
# Epoch 23/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4350 - accuracy: 0.3596
# Epoch 24/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.4045
# Epoch 25/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4327 - accuracy: 0.4157
# Epoch 26/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.4831
# Epoch 27/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4075 - accuracy: 0.5506
# Epoch 28/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.4944
# Epoch 29/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.5618
# Epoch 30/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4112 - accuracy: 0.4831
# Epoch 31/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4033 - accuracy: 0.5506
# Epoch 32/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.5955
# Epoch 33/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.5618
# Epoch 34/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3907 - accuracy: 0.5393
# Epoch 35/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.5281
# Epoch 36/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3824 - accuracy: 0.5730
# Epoch 37/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.6180
# Epoch 38/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.5506
# Epoch 39/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.6180
# Epoch 40/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.5281
# Epoch 41/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.6180
# Epoch 42/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.6742
# Epoch 43/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.6742
# Epoch 44/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3770 - accuracy: 0.5618
# Epoch 45/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.6629
# Epoch 46/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.6067
# Epoch 47/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.6742
# Epoch 48/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3581 - accuracy: 0.7303
# Epoch 49/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3607 - accuracy: 0.6517
# Epoch 50/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.6404
# Epoch 51/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3588 - accuracy: 0.6854
# Epoch 52/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.6742
# Epoch 53/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3302 - accuracy: 0.6854
# Epoch 54/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3472 - accuracy: 0.6854
# Epoch 55/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.7528
# Epoch 56/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.6629
# Epoch 57/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.7303
# Epoch 58/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.7191
# Epoch 59/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3362 - accuracy: 0.6966
# Epoch 60/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3260 - accuracy: 0.7303
# Epoch 61/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.7191
# Epoch 62/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3243 - accuracy: 0.6966
# Epoch 63/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3273 - accuracy: 0.7640
# Epoch 64/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3218 - accuracy: 0.7528
# Epoch 65/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3157 - accuracy: 0.7191
# Epoch 66/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3174 - accuracy: 0.7528
# Epoch 67/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3181 - accuracy: 0.7191
# Epoch 68/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3139 - accuracy: 0.7865
# Epoch 69/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3199 - accuracy: 0.7528
# Epoch 70/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3074 - accuracy: 0.7640
# Epoch 71/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3141 - accuracy: 0.7865
# Epoch 72/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3103 - accuracy: 0.7416
# Epoch 73/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3069 - accuracy: 0.7640
# Epoch 74/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.7528
# Epoch 75/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3045 - accuracy: 0.7865
# Epoch 76/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3020 - accuracy: 0.7528
# Epoch 77/120
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2954 - accuracy: 0.7865
# Epoch 78/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.8315
# Epoch 79/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3056 - accuracy: 0.8090
# Epoch 80/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2983 - accuracy: 0.7978
# Epoch 81/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3041 - accuracy: 0.7978
# Epoch 82/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2913 - accuracy: 0.7753
# Epoch 83/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2978 - accuracy: 0.7978
# Epoch 84/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2946 - accuracy: 0.7753
# Epoch 85/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2899 - accuracy: 0.7528
# Epoch 86/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.7978
# Epoch 87/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2759 - accuracy: 0.8202
# Epoch 88/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2813 - accuracy: 0.8202
# Epoch 89/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2854 - accuracy: 0.7416
# Epoch 90/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2835 - accuracy: 0.7753
# Epoch 91/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2683 - accuracy: 0.8202
# Epoch 92/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.7753
# Epoch 93/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.8090
# Epoch 94/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2799 - accuracy: 0.8090
# Epoch 95/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.7865
# Epoch 96/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 0.8315
# Epoch 97/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.7640
# Epoch 98/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.8090
# Epoch 99/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2750 - accuracy: 0.7640
# Epoch 100/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2648 - accuracy: 0.8315
# Epoch 101/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.8090
# Epoch 102/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2716 - accuracy: 0.8202
# Epoch 103/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2579 - accuracy: 0.8202
# Epoch 104/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2732 - accuracy: 0.7753
# Epoch 105/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2780 - accuracy: 0.7640
# Epoch 106/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.8315
# Epoch 107/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2681 - accuracy: 0.7640
# Epoch 108/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.8315
# Epoch 109/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.8202
# Epoch 110/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.8202
# Epoch 111/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.7978
# Epoch 112/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2594 - accuracy: 0.7865
# Epoch 113/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.7865
# Epoch 114/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2386 - accuracy: 0.8090
# Epoch 115/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.8315
# Epoch 116/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.8315
# Epoch 117/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.7978
# Epoch 118/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2439 - accuracy: 0.8539
# Epoch 119/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.8090
# Epoch 120/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2455 - accuracy: 0.8427

# %%
inp1 = tf.keras.layers.Input(shape=(13,))
dropout11 =  tf.keras.layers.Dropout(.3)(inp1)
hidden_11 =  tf.keras.layers.Dense(64, activation='LeakyReLU')(dropout11) 
out1 =  tf.keras.layers.Dense(3, activation='softmax')(hidden_11)

model2 = tf.keras.Model(inputs=inp1, outputs=out1)

# %%
model2.compile(optimizer = tf.keras.optimizers.RMSprop(),
        loss = 'mean_absolute_error',
               metrics=['accuracy'])

# %%
model2.fit(x_train,y_train, epochs = 25, batch_size = batchSize)
# Out:
# Epoch 1/25
# 9/9 [==============================] - 1s 2ms/step - loss: 0.3190 - accuracy: 0.6966
# Epoch 2/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.7528
# Epoch 3/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.8090
# Epoch 4/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1934 - accuracy: 0.8427
# Epoch 5/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.8539
# Epoch 6/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9213
# Epoch 7/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.9438
# Epoch 8/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 0.8989
# Epoch 9/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1213 - accuracy: 0.8876
# Epoch 10/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9326
# Epoch 11/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.9213
# Epoch 12/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.9326
# Epoch 13/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0927 - accuracy: 0.9326
# Epoch 14/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9326
# Epoch 15/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 0.9551
# Epoch 16/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0879 - accuracy: 0.9213
# Epoch 17/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0795 - accuracy: 0.9213
# Epoch 18/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9438
# Epoch 19/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9551
# Epoch 20/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9663
# Epoch 21/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9213
# Epoch 22/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9775
# Epoch 23/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0672 - accuracy: 0.8989
# Epoch 24/25
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0608 - accuracy: 0.9551
# Epoch 25/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 0.9663

# %%
inp2 = tf.keras.layers.Input(shape=(13,))
hidden_12 =  tf.keras.layers.Dense(64, activation='LeakyReLU')(inp2)
dropout12 =  tf.keras.layers.Dropout(.2)(hidden_12)
hidden_22 =  tf.keras.layers.Dense(64, activation='LeakyReLU')(dropout12) 
out2 =  tf.keras.layers.Dense(3, activation='softmax')(hidden_22)

model3 = tf.keras.Model(inputs=inp2, outputs=out2)

model3.compile(optimizer = tf.keras.optimizers.Adagrad(),
               loss = 'mean_absolute_error',
               metrics=['accuracy'])

# %%
model3.fit(x_train,y_train, epochs = 120, batch_size = batchSize)
# Out:
# Epoch 1/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4382 - accuracy: 0.4045
# Epoch 2/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.4157
# Epoch 3/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.4045
# Epoch 4/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4190 - accuracy: 0.4494
# Epoch 5/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.5169
# Epoch 6/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.5056
# Epoch 7/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4174 - accuracy: 0.4944
# Epoch 8/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.5056
# Epoch 9/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.5730
# Epoch 10/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.5843
# Epoch 11/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.6067
# Epoch 12/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.5730
# Epoch 13/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.5843
# Epoch 14/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3772 - accuracy: 0.6966
# Epoch 15/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.6292
# Epoch 16/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3878 - accuracy: 0.5730
# Epoch 17/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3666 - accuracy: 0.7191
# Epoch 18/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3652 - accuracy: 0.6629
# Epoch 19/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.7191
# Epoch 20/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.6966
# Epoch 21/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.7191
# Epoch 22/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3534 - accuracy: 0.7303
# Epoch 23/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3503 - accuracy: 0.7416
# Epoch 24/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3433 - accuracy: 0.7753
# Epoch 25/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3522 - accuracy: 0.7416
# Epoch 26/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.7416
# Epoch 27/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.7640
# Epoch 28/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.7640
# Epoch 29/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.7528
# Epoch 30/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3292 - accuracy: 0.7640
# Epoch 31/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.7079
# Epoch 32/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.7753
# Epoch 33/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.7753
# Epoch 34/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.7753
# Epoch 35/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3128 - accuracy: 0.8090
# Epoch 36/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3128 - accuracy: 0.7640
# Epoch 37/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3112 - accuracy: 0.7640
# Epoch 38/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3062 - accuracy: 0.7865
# Epoch 39/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3128 - accuracy: 0.7753
# Epoch 40/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3054 - accuracy: 0.8090
# Epoch 41/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3037 - accuracy: 0.8090
# Epoch 42/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.7865
# Epoch 43/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2906 - accuracy: 0.8315
# Epoch 44/120
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2941 - accuracy: 0.7865
# Epoch 45/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.8090
# Epoch 46/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2897 - accuracy: 0.7978
# Epoch 47/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2872 - accuracy: 0.8090
# Epoch 48/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2876 - accuracy: 0.8315
# Epoch 49/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2906 - accuracy: 0.7865
# Epoch 50/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2852 - accuracy: 0.8090
# Epoch 51/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2776 - accuracy: 0.7865
# Epoch 52/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8315
# Epoch 53/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.8202
# Epoch 54/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.8202
# Epoch 55/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.8427
# Epoch 56/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2693 - accuracy: 0.8090
# Epoch 57/120
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2672 - accuracy: 0.8315
# Epoch 58/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.7978
# Epoch 59/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.8539
# Epoch 60/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2626 - accuracy: 0.8202
# Epoch 61/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.8539
# Epoch 62/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.7978
# Epoch 63/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2594 - accuracy: 0.8315
# Epoch 64/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2597 - accuracy: 0.8202
# Epoch 65/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.8315
# Epoch 66/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.8315
# Epoch 67/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.8202
# Epoch 68/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.8427
# Epoch 69/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.8202
# Epoch 70/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.8427
# Epoch 71/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.8427
# Epoch 72/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.8539
# Epoch 73/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2382 - accuracy: 0.8202
# Epoch 74/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.8202
# Epoch 75/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.8427
# Epoch 76/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.8539
# Epoch 77/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2360 - accuracy: 0.8315
# Epoch 78/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2301 - accuracy: 0.8539
# Epoch 79/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.8539
# Epoch 80/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2296 - accuracy: 0.8652
# Epoch 81/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.8652
# Epoch 82/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.8427
# Epoch 83/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.8652
# Epoch 84/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2247 - accuracy: 0.8202
# Epoch 85/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2259 - accuracy: 0.8652
# Epoch 86/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.8202
# Epoch 87/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2203 - accuracy: 0.8539
# Epoch 88/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2253 - accuracy: 0.8315
# Epoch 89/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.8764
# Epoch 90/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2183 - accuracy: 0.8652
# Epoch 91/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2170 - accuracy: 0.8427
# Epoch 92/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.8652
# Epoch 93/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2179 - accuracy: 0.8539
# Epoch 94/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2152 - accuracy: 0.8652
# Epoch 95/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2110 - accuracy: 0.8764
# Epoch 96/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2134 - accuracy: 0.8315
# Epoch 97/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2042 - accuracy: 0.8427
# Epoch 98/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1997 - accuracy: 0.8427
# Epoch 99/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2031 - accuracy: 0.8652
# Epoch 100/120
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2059 - accuracy: 0.8652
# Epoch 101/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2057 - accuracy: 0.8539
# Epoch 102/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2037 - accuracy: 0.8315
# Epoch 103/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2032 - accuracy: 0.8539
# Epoch 104/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2049 - accuracy: 0.8876
# Epoch 105/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1989 - accuracy: 0.8652
# Epoch 106/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.8539
# Epoch 107/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2057 - accuracy: 0.8315
# Epoch 108/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1998 - accuracy: 0.8315
# Epoch 109/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2010 - accuracy: 0.8539
# Epoch 110/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.8652
# Epoch 111/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.8989
# Epoch 112/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.8876
# Epoch 113/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1931 - accuracy: 0.8539
# Epoch 114/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1903 - accuracy: 0.8764
# Epoch 115/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.8652
# Epoch 116/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.8989
# Epoch 117/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.8764
# Epoch 118/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1837 - accuracy: 0.8876
# Epoch 119/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1925 - accuracy: 0.8876
# Epoch 120/120
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1918 - accuracy: 0.8539

# %%
inp3 = tf.keras.layers.Input(shape=(13,)) 
hidden_13 =  tf.keras.layers.Dense(64, activation='LeakyReLU')(inp3)
dropout13 =  tf.keras.layers.Dropout(.3)(hidden_13)
hidden_23 =  tf.keras.layers.Dense(64, activation='LeakyReLU')(dropout13) 
out3 =  tf.keras.layers.Dense(3, activation='softmax')(hidden_23)

model4 = tf.keras.Model(inputs=inp3, outputs=out3)

model4.compile(optimizer = tf.keras.optimizers.RMSprop(),
               loss = 'mean_absolute_error',
               metrics=['accuracy'])

# %%
model4.fit(x_train,y_train, epochs = 25, batch_size = batchSize)
# Out:
# Epoch 1/25
# 9/9 [==============================] - 1s 2ms/step - loss: 0.3898 - accuracy: 0.5843
# Epoch 2/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.9101
# Epoch 3/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1708 - accuracy: 0.8989
# Epoch 4/25
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9551
# Epoch 5/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9551
# Epoch 6/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9663
# Epoch 7/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9663
# Epoch 8/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9775
# Epoch 9/25
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9775
# Epoch 10/25
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 0.9663
# Epoch 11/25
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 0.9888
# Epoch 12/25
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 0.9888
# Epoch 13/25
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.9775
# Epoch 14/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9775
# Epoch 15/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 16/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9775
# Epoch 17/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9888
# Epoch 18/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9775
# Epoch 19/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9888
# Epoch 20/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9888
# Epoch 21/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 22/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9888
# Epoch 23/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9888
# Epoch 24/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 25/25
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.9888

# %%
loss_value1, accuracy_value1 = model1.evaluate(x_test,y_test,batch_size=batchSize)
loss_value2, accuracy_value2 = model2.evaluate(x_test,y_test,batch_size=batchSize, verbose = 0)
loss_value3, accuracy_value3 = model3.evaluate(x_test,y_test,batch_size=batchSize, verbose = 0)
loss_value4, accuracy_value4 = model4.evaluate(x_test,y_test,batch_size=batchSize, verbose = 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.8315

# %%
d = {'model1': [loss_value1, accuracy_value1],
     'model2': [loss_value2,  accuracy_value2],
     'model3': [loss_value3, accuracy_value3],
     'model4': [loss_value4,  accuracy_value4]}

df = pd.DataFrame(data=d, index=["loss_value", "accuracy_value"])
df
# Out:
#                   model1    model2    model3    model4
# loss_value      0.233750  0.038172  0.160506  0.022368
# accuracy_value  0.831461  0.955056  0.898876  0.966292

# %%
i = 0.1
iList = []
temp1 = []
temp2 = []
temp3 = []
temp4 = []

while i <= 0.9:
    x_train, x_test, y_train, y_test = train_test_split(data, target,random_state = 1, train_size=i, shuffle=True)
    y_train = tf.keras.utils.to_categorical(y_train, num_classes)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes)
    scaler = StandardScaler().fit(x_train)
    x_train = scaler.transform(x_train)
    x_test = scaler.transform(x_test)
    
    model1.fit(x_train, y_train, epochs = 120, batch_size = batchSize, verbose = 0)
    model2.fit(x_train, y_train, epochs = 25, batch_size = batchSize, verbose = 0)
    model3.fit(x_train, y_train, epochs = 120, batch_size = batchSize, verbose = 0)
    model4.fit(x_train, y_train, epochs = 25, batch_size = batchSize, verbose = 0)
    
    loss_value1, accuracy_value1 = model1.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value2, accuracy_value2 = model2.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value3, accuracy_value3 = model3.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value4, accuracy_value4 = model4.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    #print(accuracy_value1)
    
    temp1.append({'Model1': accuracy_value1,'Model2': accuracy_value2, 'Model3': accuracy_value3, 'Model4': accuracy_value4})
    temp2.append({'Model1': loss_value1, 'Model2': loss_value2, 'Model3': loss_value3, 'Model4': loss_value4})
    
    loss_value1, accuracy_value1 = model1.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value2, accuracy_value2 = model2.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value3, accuracy_value3 = model3.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value4, accuracy_value4 = model4.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    #print(accuracy_value1)
    
    temp3.append({'Model1': accuracy_value1,'Model2': accuracy_value2, 'Model3': accuracy_value3, 'Model4': accuracy_value4})
    temp4.append({'Model1': loss_value1, 'Model2': loss_value2, 'Model3': loss_value3, 'Model4': loss_value4})
    
    iList.append(round(1-i,1))
    i += 0.1
    
accuracyDataTrain = pd.DataFrame(temp1)
lossDataTrain = pd.DataFrame(temp2)
accuracyDataTest = pd.DataFrame(temp3)
lossDataTest = pd.DataFrame(temp4)

# %%
accuracyDataTrain
# Out:
#      Model1    Model2    Model3  Model4
# 0  0.823529  1.000000  0.882353     1.0
# 1  0.857143  1.000000  0.914286     1.0
# 2  0.924528  1.000000  0.943396     1.0
# 3  0.943662  1.000000  0.985915     1.0
# 4  0.943820  0.988764  0.988764     1.0
# 5  0.952830  0.990566  0.990566     1.0
# 6  0.959677  0.983871  0.991935     1.0
# 7  0.985915  0.992958  0.992958     1.0
# 8  0.987500  0.993750  0.993750     1.0

# %%
from matplotlib import pyplot as plt
fig,(ax1, ax2, ax3, ax4) = plt.subplots(4,figsize=(8, 20))
fig.suptitle('Зависимость функций аккуратности и ошибки от объема обучающей выборки при обучении и классификации')
x_lable='Объем обучающей выборки'
y1_lable='Значение функции аккуратности от размера обучающей выборки'
y2_lable='Значение функции ошибки от размера обучающей выборки'
y3_lable='Значение функции аккуратности при классификации'
y4_lable='Значение функции ошибки при классификации'

ax1.set_xlabel(x_lable) 
ax1.set_ylabel(y1_lable)
ax2.set_xlabel(x_lable) 
ax2.set_ylabel(y2_lable)
ax3.set_xlabel(x_lable) 
ax3.set_ylabel(y3_lable)
ax4.set_xlabel(x_lable) 
ax4.set_ylabel(y4_lable)

ax1.plot(iList, accuracyDataTrain.Model1, label='model1') 
ax1.plot(iList, accuracyDataTrain.Model2, label='model2')
ax1.plot(iList, accuracyDataTrain.Model3, label='model3') 
ax1.plot(iList, accuracyDataTrain.Model4, label='model4')

ax2.plot(iList, lossDataTrain.Model1, label='model1') 
ax2.plot(iList, lossDataTrain.Model2, label='model2')
ax2.plot(iList, lossDataTrain.Model3, label='model3') 
ax2.plot(iList, lossDataTrain.Model4, label='model4')

ax3.plot(iList, accuracyDataTest.Model1, label='model1') 
ax3.plot(iList, accuracyDataTest.Model2, label='model2')
ax3.plot(iList, accuracyDataTest.Model3, label='model3') 
ax3.plot(iList, accuracyDataTest.Model4, label='model4')

ax4.plot(iList, lossDataTest.Model1, label='model1') 
ax4.plot(iList, lossDataTest.Model2, label='model2')
ax4.plot(iList, lossDataTest.Model3, label='model3') 
ax4.plot(iList, lossDataTest.Model4, label='model4')

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

# %%
iList = []
temp1 = []
temp2 = []
temp3 = []
temp4 = []
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2, shuffle=True)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
i = 1

while i <= 40:
    
    model1.fit(x_train, y_train, epochs = i, batch_size = batchSize, verbose = 0)
    model2.fit(x_train, y_train, epochs = i, batch_size = batchSize, verbose = 0)
    model3.fit(x_train, y_train, epochs = i, batch_size = batchSize, verbose = 0)
    model4.fit(x_train, y_train, epochs = i, batch_size = batchSize, verbose = 0)
    
    loss_value1, accuracy_value1 = model1.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value2, accuracy_value2 = model2.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value3, accuracy_value3 = model3.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value4, accuracy_value4 = model4.evaluate(x_train , y_train, batch_size=batchSize, verbose = 0)
    
    temp1.append({'Model1': accuracy_value1,'Model2': accuracy_value2, 'Model3': accuracy_value3, 'Model4': accuracy_value4})
    temp2.append({'Model1': loss_value1, 'Model2': loss_value2, 'Model3': loss_value3, 'Model4': loss_value4})
    
    loss_value1, accuracy_value1 = model1.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value2, accuracy_value2 = model2.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value3, accuracy_value3 = model3.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value4, accuracy_value4 = model4.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    
    temp3.append({'Model1': accuracy_value1,'Model2': accuracy_value2, 'Model3': accuracy_value3, 'Model4': accuracy_value4})
    temp4.append({'Model1': loss_value1, 'Model2': loss_value2, 'Model3': loss_value3, 'Model4': loss_value4})
    
    iList.append(round(i,0))
    i += 10

accuracyDataTrain = pd.DataFrame(temp1)
lossDataTrain = pd.DataFrame(temp2)
accuracyDataTest = pd.DataFrame(temp3)
lossDataTest = pd.DataFrame(temp4)

# %%
from matplotlib import pyplot as plt
fig,(ax1, ax2, ax3, ax4) = plt.subplots(4,figsize=(8, 20))
fig.suptitle('Зависимость функций аккуратности и ошибки от числа эпох при обучении и классификации')
x_lable='Число эпох'
y1_lable='Значение функции аккуратности при обучении'
y2_lable='Значение функции ошибки при обучении'
y3_lable='Значение функции аккуратности при классификации'
y4_lable='Значение функции ошибки при классификации'

ax1.set_xlabel(x_lable) 
ax1.set_ylabel(y1_lable)
ax2.set_xlabel(x_lable) 
ax2.set_ylabel(y2_lable)
ax3.set_xlabel(x_lable) 
ax3.set_ylabel(y3_lable)
ax4.set_xlabel(x_lable) 
ax4.set_ylabel(y4_lable)

ax1.plot(iList, accuracyDataTrain.Model1, label='model1') 
ax1.plot(iList, accuracyDataTrain.Model2, label='model2')
ax1.plot(iList, accuracyDataTrain.Model3, label='model3') 
ax1.plot(iList, accuracyDataTrain.Model4, label='model4')

ax2.plot(iList, lossDataTrain.Model1, label='model1') 
ax2.plot(iList, lossDataTrain.Model2, label='model2')
ax2.plot(iList, lossDataTrain.Model3, label='model3') 
ax2.plot(iList, lossDataTrain.Model4, label='model4')

ax3.plot(iList, accuracyDataTest.Model1, label='model1') 
ax3.plot(iList, accuracyDataTest.Model2, label='model2')
ax3.plot(iList, accuracyDataTest.Model3, label='model3') 
ax3.plot(iList, accuracyDataTest.Model4, label='model4')

ax4.plot(iList, lossDataTest.Model1, label='model1') 
ax4.plot(iList, lossDataTest.Model2, label='model2')
ax4.plot(iList, lossDataTest.Model3, label='model3') 
ax4.plot(iList, lossDataTest.Model4, label='model4')

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

# %%
x_train, x_test, y_train,y_test = train_test_split(data, target, random_state=652, test_size=0.2, shuffle=True)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

model1.fit(x_train,y_train, epochs = 120, batch_size = batchSize, verbose = 0)
model2.fit(x_train,y_train, epochs = 25, batch_size = batchSize, verbose = 0)
model3.fit(x_train,y_train, epochs = 120, batch_size = batchSize, verbose = 0)
model4.fit(x_train,y_train, epochs = 25, batch_size = batchSize, verbose = 0)

    
true_labels = np.argmax(y_test, axis = 1)
print(true_labels)
pred1 = model1.predict(x_test)
pred1 = np.argmax(pred1, axis =1)
pred2 = model2.predict(x_test)
pred2 = np.argmax(pred2, axis =1)
pred3 = model3.predict(x_test)
pred3 = np.argmax(pred3, axis =1)
pred4 = model4.predict(x_test)
pred4 = np.argmax(pred4, axis =1)

#print("Значения метрик для model1")
#print(classification_report(true_labels, pred1, zero_division=0))
#print("Значения метрик для model2")
#print(classification_report(true_labels, pred2, zero_division=0))
print("Значения метрик для model3")
print(classification_report(true_labels, pred3, zero_division=0))
print("Значения метрик для model4")
print(classification_report(true_labels, pred4, zero_division=0))
# Out:
# [1 1 0 0 1 1 2 2 1 1 1 0 0 2 2 0 1 1 0 1 0 1 1 1 2 1 0 1 2 2 1 1 0 2 1 1]
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# Значения метрик для model3
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Значения метрик для model4
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
fpr1, tpr1, thresholds1 = roc_curve(true_labels, pred1, pos_label=2)
fpr2, tpr2, thresholds2 = roc_curve(true_labels, pred2, pos_label=2)
fpr3, tpr3, thresholds3 = roc_curve(true_labels, pred3, pos_label=2)
fpr4, tpr4, thresholds4 = roc_curve(true_labels, pred4, pos_label=2)
auc_score1 = auc(fpr1, tpr1)
auc_score2 = auc(fpr2, tpr2)
auc_score3 = auc(fpr3, tpr3)
auc_score4 = auc(fpr4, tpr4)
print("Площадь AUC model1 - " + str(auc_score1))
print("Площадь AUC model2 - " + str(auc_score2))
print("Площадь AUC model3 - " + str(auc_score3))
print("Площадь AUC model4 - " + str(auc_score4))
plt.plot([0, 1], [0, 1], lw=2, color='r',label='Random', alpha=0.5)
plt.plot(fpr1,tpr1, label="ROC Curve model1",color="cyan")
plt.plot(fpr2,tpr2, label="ROC Curve model2",color="green", linestyle='dotted')
plt.plot(fpr3,tpr3, label="ROC Curve model3",color="purple", linestyle='dashdot')
plt.plot(fpr4,tpr4, label="ROC Curve model4",color="blue", linestyle='--')
plt.xlabel("False Positve Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Out:
# Площадь AUC model1 - 1.0
# Площадь AUC model2 - 1.0
# Площадь AUC model3 - 1.0
# Площадь AUC model4 - 1.0

# %%
print("Confusion matrics для model1")
cm = confusion_matrix(true_labels, pred1)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Confusion matrics для model1

# %%
print("Confusion matrics для model2")
cm = confusion_matrix(true_labels, pred2)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Confusion matrics для model2

# %%
print("Confusion matrics для model3")
cm = confusion_matrix(true_labels, pred3)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Confusion matrics для model3

# %%
print("Confusion matrics для model4")
cm = confusion_matrix(true_labels, pred4)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Confusion matrics для model4

# %%
i = 0.2
iList = []
temp1 = []
temp2 = []
temp3 = []
temp4 = []
x_train, x_test, y_train,y_test = train_test_split(data, target, random_state=1,test_size=0.2,shuffle=True)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
while i <= 0.5:
    
    inp_dr = tf.keras.layers.Input(shape=(13,)) 
    dropout1_dr =  tf.keras.layers.Dropout(i)(inp_dr)
    hidden_1_dr =  tf.keras.layers.Dense(64, activation='LeakyReLU')(dropout1_dr)
    out_dr =  tf.keras.layers.Dense(3, activation='softmax')(hidden_1_dr)
    model1_dr = tf.keras.Model(inputs=inp_dr, outputs=out_dr)
    model1_dr.compile(optimizer = tf.keras.optimizers.Adagrad(),
    loss = 'mean_absolute_error',
    metrics=['accuracy'])
    model1_dr.fit(x_train,y_train,epochs=120,batch_size=batchSize, verbose = 0)
    
    
    inp1_dr = tf.keras.layers.Input(shape=(13,))
    dropout11_dr =  tf.keras.layers.Dropout(i)(inp1_dr)
    hidden_11_dr =  tf.keras.layers.Dense(64, activation='LeakyReLU')(dropout11_dr) 
    out1_dr =  tf.keras.layers.Dense(3, activation='softmax')(hidden_11_dr)
    model2_dr = tf.keras.Model(inputs=inp1_dr, outputs=out1_dr)
    model2_dr.compile(optimizer = tf.keras.optimizers.RMSprop(),
    loss = 'mean_absolute_error',
    metrics =['accuracy'])
    model2_dr.fit(x_train,y_train, epochs = 25, batch_size = batchSize, verbose = 0)
    
    
    inp2_dr = tf.keras.layers.Input(shape=(13,))
    hidden_12_dr =  tf.keras.layers.Dense(64, activation='LeakyReLU')(inp2_dr)
    dropout12_dr =  tf.keras.layers.Dropout(i)(hidden_12_dr)
    hidden_22_dr =  tf.keras.layers.Dense(64, activation='LeakyReLU')(dropout12_dr) 
    out2_dr =  tf.keras.layers.Dense(3, activation='softmax')(hidden_22_dr)
    model3_dr = tf.keras.Model(inputs=inp2_dr, outputs=out2_dr)
    model3_dr.compile(optimizer = tf.keras.optimizers.Adagrad(),
    loss = 'mean_absolute_error',
    metrics =['accuracy'])
    model3_dr.fit(x_train,y_train, epochs = 120, batch_size = batchSize, verbose = 0)
    
    
    inp3_dr = tf.keras.layers.Input(shape=(13,)) 
    hidden_13_dr =  tf.keras.layers.Dense(64, activation='LeakyReLU')(inp3_dr)
    dropout13_dr =  tf.keras.layers.Dropout(i)(hidden_13_dr)
    hidden_23_dr =  tf.keras.layers.Dense(64, activation='LeakyReLU')(dropout13_dr) 
    out3_dr =  tf.keras.layers.Dense(3, activation='softmax')(hidden_23_dr)
    model4_dr = tf.keras.Model(inputs=inp3_dr, outputs=out3_dr)
    model4_dr.compile(optimizer = tf.keras.optimizers.RMSprop(),
    loss = 'mean_absolute_error',
    metrics =['accuracy'])
    model4_dr.fit(x_train,y_train, epochs = 25, batch_size = batchSize, verbose = 0)
    
    
    
    model1_dr.fit(x_train, y_train, epochs = 20, batch_size = batchSize, verbose = 0)
    model2_dr.fit(x_train, y_train, epochs = 20, batch_size = batchSize, verbose = 0)
    model3_dr.fit(x_train, y_train, epochs = 20, batch_size = batchSize, verbose = 0)
    model4_dr.fit(x_train, y_train, epochs = 20, batch_size = batchSize, verbose = 0)
    
    loss_value1, accuracy_value1 = model1_dr.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value2, accuracy_value2 = model2_dr.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value3, accuracy_value3 = model3_dr.evaluate(x_train, y_train, batch_size=batchSize, verbose = 0)
    loss_value4, accuracy_value4 = model4_dr.evaluate(x_train , y_train, batch_size=batchSize, verbose = 0)
    
    temp1.append({'Model1': accuracy_value1,'Model2': accuracy_value2, 'Model3': accuracy_value3, 'Model4': accuracy_value4})
    temp2.append({'Model1': loss_value1, 'Model2': loss_value2, 'Model3': loss_value3, 'Model4': loss_value4})
    
    loss_value1, accuracy_value1 = model1_dr.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value2, accuracy_value2 = model2_dr.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value3, accuracy_value3 = model3_dr.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    loss_value4, accuracy_value4 = model4_dr.evaluate(x_test, y_test, batch_size=batchSize, verbose = 0)
    
    temp3.append({'Model1': accuracy_value1,'Model2': accuracy_value2, 'Model3': accuracy_value3, 'Model4': accuracy_value4})
    temp4.append({'Model1': loss_value1, 'Model2': loss_value2, 'Model3': loss_value3, 'Model4': loss_value4})
    
    
    
    iList.append(round(i,1))
    i += 0.1
    
accuracyDataTrain = pd.DataFrame(temp1)
lossDataTrain = pd.DataFrame(temp2)
accuracyDataTest = pd.DataFrame(temp3)
lossDataTest = pd.DataFrame(temp4)

# %%
from matplotlib import pyplot as plt
fig,(ax1, ax2, ax3, ax4) = plt.subplots(4,figsize=(8, 20))
fig.suptitle('Зависимость функций аккуратности и ошибки от размера dropout при классификации')
x_lable='Размер dropout'
y1_lable='Значение функции аккуратности при обучении'
y2_lable='Значение функции ошибки при обучении'
y3_lable='Значение функции аккуратности при классификации'
y4_lable='Значение функции ошибки при классификации'

ax1.set_xlabel(x_lable) 
ax1.set_ylabel(y1_lable)
ax2.set_xlabel(x_lable) 
ax2.set_ylabel(y2_lable)
ax3.set_xlabel(x_lable) 
ax3.set_ylabel(y3_lable)
ax4.set_xlabel(x_lable) 
ax4.set_ylabel(y4_lable)

ax1.plot(iList, accuracyDataTrain.Model1, label='model1') 
ax1.plot(iList, accuracyDataTrain.Model2, label='model2')
ax1.plot(iList, accuracyDataTrain.Model3, label='model3') 
ax1.plot(iList, accuracyDataTrain.Model4, label='model4')

ax2.plot(iList, lossDataTrain.Model1, label='model1') 
ax2.plot(iList, lossDataTrain.Model2, label='model2')
ax2.plot(iList, lossDataTrain.Model3, label='model3') 
ax2.plot(iList, lossDataTrain.Model4, label='model4')

ax3.plot(iList, accuracyDataTest.Model1, label='model1') 
ax3.plot(iList, accuracyDataTest.Model2, label='model2')
ax3.plot(iList, accuracyDataTest.Model3, label='model3') 
ax3.plot(iList, accuracyDataTest.Model4, label='model4')

ax4.plot(iList, lossDataTest.Model1, label='model1') 
ax4.plot(iList, lossDataTest.Model2, label='model2')
ax4.plot(iList, lossDataTest.Model3, label='model3') 
ax4.plot(iList, lossDataTest.Model4, label='model4')

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()
